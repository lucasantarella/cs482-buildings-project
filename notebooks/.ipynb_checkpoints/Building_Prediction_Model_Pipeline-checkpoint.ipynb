# %% [markdown]
# Please use the following cells to check if your GPU is accessible within this notebook

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.sysconfig.get_build_info()
# Out:
# 2023-07-15 22:04:12.401970: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-15 22:04:12.423730: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-15 22:04:12.784423: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Num GPUs Available:  1
# 2023-07-15 22:04:13.175727: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:04:13.189695: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:04:13.189774: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# OrderedDict([('cpu_compiler', '/usr/lib/llvm-16/bin/clang'),
#              ('cuda_compute_capabilities',
#               ['sm_35', 'sm_50', 'sm_60', 'sm_70', 'sm_75', 'compute_80']),
#              ('cuda_version', '11.8'),
#              ('cudnn_version', '8'),
#              ('is_cuda_build', True),
#              ('is_rocm_build', False),
#              ('is_tensorrt_build', True)])

# %% [markdown]
# This repo provides a dockerfile for setting up a container to run this code in. Once that docker container is running, we will need some more installations before we can start building or training pipeline.

# %%
#should really be mostly "requirements already satisfied:" but just in case

# #some installations that our framework depends on 
# !pip install keras
# !pip install tifffile

# #for mask generation
# !pip install rasterio
# !pip install geopandas
# !pip install gdal
# !pip install opencv-python

# %% [markdown]
# Here we have torch to accomodate the framework we will be using. We will be training a Unet neural network for feature extraction and to generate mask images.
#
# The repo we are using is modified slightly to accomodate this project folder structure and is a fork of [this repo](https://github.com/reachsumit/deep-unet-for-satellite-image-segmentation/)

# %%
# !ls ~/deep-unet-for-satellite-image-segmentation
# Out:
# README.md    gen_patches.py  predict.py        train_unet.py	     weights
# __pycache__  log_unet.csv    run.sbatch        unet_model.py
# data	     map.tif	     tensorboard_unet  unet_model_deeper.py

# %% [markdown]
# We have already cloned the repo into our lib folder. If you need to do this you can use the git command with the link provided above
#
# Ok now we have that repo locally. Before we start actually building the pipeline, lets see what our data looks like. Below I will print out a couple images to see what we are working with

# %%
import numpy as np
import matplotlib.pyplot as plt # display image
from rasterio.plot import reshape_as_image
from osgeo import gdal
import os
import random

# %%
filelocs = ['/home/jovyan/data/train/RGB-PanSharpen/RGB-PanSharpen_AOI_3_Paris_img100.tif',
            '/home/jovyan/data/train/RGB-PanSharpen/RGB-PanSharpen_AOI_3_Paris_img107.tif',
            '/home/jovyan/data/train/RGB-PanSharpen/RGB-PanSharpen_AOI_3_Paris_img111.tif',
            '/home/jovyan/data/train/RGB-PanSharpen/RGB-PanSharpen_AOI_3_Paris_img128.tif',
            '/home/jovyan/data/train/RGB-PanSharpen/RGB-PanSharpen_AOI_3_Paris_img158.tif']
# Read File Raster Data as Array using Gdal
rasters = []
for x in filelocs:
    gtif = gdal.Open(x)
    rasters.append(gtif.ReadAsArray())

plt.subplots(1,5,figsize=(25,5))
for i in range(0,len(rasters)):
    plt.subplot(1,5,i+1)
    plt.imshow(reshape_as_image(rasters[i]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Similarly, there is a folder of geojson files that contain regions for the buildings that appear in these pictures. Keep in mind that some images dont have any buildings, and this can be seen in their corresponding geojson files. The files with buildings typically have entries in the features tag whereas those with out buildings predictably don't have any such features. Here are two examples of this

# %%
print("File with no buildings\n")
# %cat ~/data/train/geojson/buildings/buildings_AOI_3_Paris_img3.geojson | head -5

print("File with buildings\n")
# %cat ~/data/train/geojson/buildings/buildings_AOI_3_Paris_img100.geojson | head -5
# Out:
# File with no buildings
#
# {
# "type": "FeatureCollection",
# "crs": { "type": "name", "properties": { "name": "urn:ogc:def:crs:OGC:1.3:CRS84" } },
#
# "features": [
# File with buildings
#
# {
# "type": "FeatureCollection",
# "crs": { "type": "name", "properties": { "name": "urn:ogc:def:crs:OGC:1.3:CRS84" } },
#
# "features": [

# %% [markdown]
# You can see that one json is small and has no features whereas the other has about 30 features
#
# Alright now here is maybe the hardest part of the pipeline creation, we have to format our data a little. We need to convert the geojsons that we have to json. Once that is done, the hard part is over. All we need to do is feed this data to the train script we have obtained from Unet. After that we are ready to test the model on our other set of data.

# %% [markdown]
# Using [this](https://lpsmlgeo.github.io/2019-09-22-binary_mask/#4-generate-the-binary-mask) link, we have modified the code that is provided there to generate masks for us, and the py file for this is provided in this repo as generate_masks_from_geojson.py.

# %%
#Use this as needed in case you need to reset the masks folder
# !rm ~/data/train/Masks/*

# %%
paths = ["/home/jovyan/data/train/geojson/buildings" , #geojsons
         "/home/jovyan/data/train/RGB-PanSharpen", #tifs
         "/home/jovyan/data/train/Masks"] #output dir
# !python3 ~/src/generate_masks_from_geojson.py {paths[0]} {paths[1]} {paths[2]}
# Out:
# tifDirList length: 1148
#
# Creating output directory if it doesnt exist
#
# Already Exists: /home/jovyan/data/train/Masks
#
# Commencing mask gen
#
# Mask gen complete. 1148 masks made. Please check your directory

# %% [markdown]
# Lets see if it worked

# %%
import os
print(os.listdir("/home/jovyan/data/train/Masks")[:10])
# Out:
# ['buildings_AOI_3_Paris_img1879.tif', 'buildings_AOI_3_Paris_img595.tif', 'buildings_AOI_3_Paris_img680.tif', 'buildings_AOI_3_Paris_img543.tif', 'buildings_AOI_3_Paris_img337.tif', 'buildings_AOI_3_Paris_img586.tif', 'buildings_AOI_3_Paris_img1057.tif', 'buildings_AOI_3_Paris_img648.tif', 'buildings_AOI_3_Paris_img1647.tif', 'buildings_AOI_3_Paris_img1320.tif']

# %% [markdown]
# The directory shows that images were indeed made at the location we specified. Lets now see the images and their corresponding masks.

# %%
gtif = gdal.Open('/home/jovyan/data/train/RGB-PanSharpen/RGB-PanSharpen_AOI_3_Paris_img746.tif')
image = gtif.ReadAsArray()

gtif = gdal.Open('/home/jovyan/data/train/Masks/buildings_AOI_3_Paris_img746.tif')
mask = gtif.ReadAsArray()
print(mask.shape)

plt.subplots(1,2,figsize=(15,5))
plt.imshow(reshape_as_image(image))
plt.subplot(1,2,1)
plt.imshow(reshape_as_image([mask]))
plt.subplot(1,2,2)
plt.show()

gtif = None
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (650, 650)

# %% [markdown]
# Here is one example of a mask made for the image above it. It shows the network where the pixels that belong to buildings are. Using this data, we will now train Unet.

# %% [markdown]
# We need to make some modifications to the repo that we downloaded earlier. Namely some of the hyperparameters like Band Size and Number of Classes, as well as all the path strings so they match the current set up. After this is all done. Simply invoke the script and it should start training a model.
#
# Since we have a large number of images (1000+), I have set it so that it will only look at the first 500 images. For each batch it takes 50 from the 500.the model augments the data by taking 160x160 size patches from the batch 1000 times. So for each batch it ends up looking at 1000 160x160 crops from the 50 images in a batch. It will do this 10000 times (10000 Epochs) so that it can  get a good understanding of the data.
#
# Alright now that we understand some of the specifics of what it is doing, lets uncomment and run the script.

# %%
# !python3 ~/deep-unet-for-satellite-image-segmentation/train_unet.py
# Out:
# 2023-07-15 22:07:57.271443: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-15 22:07:57.292082: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-15 22:07:57.655210: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-15 22:07:58.066808: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:07:58.087159: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:07:58.087253: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Weights Folder Already Exists
# getting model
# Reading images
# 1	RGB-PanSharpen_AOI_3_Paris_img943.tif read
# 2	RGB-PanSharpen_AOI_3_Paris_img648.tif read
# 3	RGB-PanSharpen_AOI_3_Paris_img1478.tif read
# 4	RGB-PanSharpen_AOI_3_Paris_img873.tif read
# 5	RGB-PanSharpen_AOI_3_Paris_img423.tif read
# 6	RGB-PanSharpen_AOI_3_Paris_img621.tif read
# 7	RGB-PanSharpen_AOI_3_Paris_img1623.tif read
# 8	RGB-PanSharpen_AOI_3_Paris_img37.tif read
# 9	RGB-PanSharpen_AOI_3_Paris_img736.tif read
# 10	RGB-PanSharpen_AOI_3_Paris_img1846.tif read
# 11	RGB-PanSharpen_AOI_3_Paris_img1327.tif read
# 12	RGB-PanSharpen_AOI_3_Paris_img1019.tif read
# 13	RGB-PanSharpen_AOI_3_Paris_img1304.tif read
# 14	RGB-PanSharpen_AOI_3_Paris_img716.tif read
# 15	RGB-PanSharpen_AOI_3_Paris_img1714.tif read
# 16	RGB-PanSharpen_AOI_3_Paris_img379.tif read
# 17	RGB-PanSharpen_AOI_3_Paris_img437.tif read
# 18	RGB-PanSharpen_AOI_3_Paris_img1135.tif read
# 19	RGB-PanSharpen_AOI_3_Paris_img952.tif read
# 20	RGB-PanSharpen_AOI_3_Paris_img1152.tif read
# 21	RGB-PanSharpen_AOI_3_Paris_img749.tif read
# 22	RGB-PanSharpen_AOI_3_Paris_img1598.tif read
# 23	RGB-PanSharpen_AOI_3_Paris_img537.tif read
# 24	RGB-PanSharpen_AOI_3_Paris_img408.tif read
# 25	RGB-PanSharpen_AOI_3_Paris_img8.tif read
# 26	RGB-PanSharpen_AOI_3_Paris_img1487.tif read
# 27	RGB-PanSharpen_AOI_3_Paris_img340.tif read
# 28	RGB-PanSharpen_AOI_3_Paris_img509.tif read
# 29	RGB-PanSharpen_AOI_3_Paris_img1244.tif read
# 30	RGB-PanSharpen_AOI_3_Paris_img564.tif read
# 31	RGB-PanSharpen_AOI_3_Paris_img495.tif read
# 32	RGB-PanSharpen_AOI_3_Paris_img748.tif read
# 33	RGB-PanSharpen_AOI_3_Paris_img1256.tif read
# 34	RGB-PanSharpen_AOI_3_Paris_img868.tif read
# 35	RGB-PanSharpen_AOI_3_Paris_img815.tif read
# 36	RGB-PanSharpen_AOI_3_Paris_img92.tif read
# 37	RGB-PanSharpen_AOI_3_Paris_img75.tif read
# 38	RGB-PanSharpen_AOI_3_Paris_img1616.tif read
# 39	RGB-PanSharpen_AOI_3_Paris_img1788.tif read
# 40	RGB-PanSharpen_AOI_3_Paris_img1050.tif read
# 41	RGB-PanSharpen_AOI_3_Paris_img1540.tif read
# 42	RGB-PanSharpen_AOI_3_Paris_img925.tif read
# 43	RGB-PanSharpen_AOI_3_Paris_img563.tif read
# 44	RGB-PanSharpen_AOI_3_Paris_img163.tif read
# 45	RGB-PanSharpen_AOI_3_Paris_img578.tif read
# 46	RGB-PanSharpen_AOI_3_Paris_img503.tif read
# 47	RGB-PanSharpen_AOI_3_Paris_img1536.tif read
# 48	RGB-PanSharpen_AOI_3_Paris_img1153.tif read
# 49	RGB-PanSharpen_AOI_3_Paris_img1748.tif read
# 50	RGB-PanSharpen_AOI_3_Paris_img1784.tif read
# 51	RGB-PanSharpen_AOI_3_Paris_img12.tif read
# 52	RGB-PanSharpen_AOI_3_Paris_img1651.tif read
# 53	RGB-PanSharpen_AOI_3_Paris_img1074.tif read
# 54	RGB-PanSharpen_AOI_3_Paris_img546.tif read
# 55	RGB-PanSharpen_AOI_3_Paris_img1405.tif read
# 56	RGB-PanSharpen_AOI_3_Paris_img1188.tif read
# 57	RGB-PanSharpen_AOI_3_Paris_img132.tif read
# 58	RGB-PanSharpen_AOI_3_Paris_img1314.tif read
# 59	RGB-PanSharpen_AOI_3_Paris_img1262.tif read
# 60	RGB-PanSharpen_AOI_3_Paris_img585.tif read
# 61	RGB-PanSharpen_AOI_3_Paris_img1423.tif read
# 62	RGB-PanSharpen_AOI_3_Paris_img411.tif read
# 63	RGB-PanSharpen_AOI_3_Paris_img1352.tif read
# 64	RGB-PanSharpen_AOI_3_Paris_img1043.tif read
# 65	RGB-PanSharpen_AOI_3_Paris_img1180.tif read
# 66	RGB-PanSharpen_AOI_3_Paris_img1397.tif read
# 67	RGB-PanSharpen_AOI_3_Paris_img1645.tif read
# 68	RGB-PanSharpen_AOI_3_Paris_img1599.tif read
# 69	RGB-PanSharpen_AOI_3_Paris_img1799.tif read
# 70	RGB-PanSharpen_AOI_3_Paris_img196.tif read
# 71	RGB-PanSharpen_AOI_3_Paris_img41.tif read
# 72	RGB-PanSharpen_AOI_3_Paris_img1035.tif read
# 73	RGB-PanSharpen_AOI_3_Paris_img1289.tif read
# 74	RGB-PanSharpen_AOI_3_Paris_img1566.tif read
# 75	RGB-PanSharpen_AOI_3_Paris_img1759.tif read
# 76	RGB-PanSharpen_AOI_3_Paris_img1030.tif read
# 77	RGB-PanSharpen_AOI_3_Paris_img1123.tif read
# 78	RGB-PanSharpen_AOI_3_Paris_img294.tif read
# 79	RGB-PanSharpen_AOI_3_Paris_img616.tif read
# 80	RGB-PanSharpen_AOI_3_Paris_img1003.tif read
# 81	RGB-PanSharpen_AOI_3_Paris_img52.tif read
# 82	RGB-PanSharpen_AOI_3_Paris_img532.tif read
# 83	RGB-PanSharpen_AOI_3_Paris_img1656.tif read
# 84	RGB-PanSharpen_AOI_3_Paris_img1562.tif read
# 85	RGB-PanSharpen_AOI_3_Paris_img738.tif read
# 86	RGB-PanSharpen_AOI_3_Paris_img1833.tif read
# 87	RGB-PanSharpen_AOI_3_Paris_img73.tif read
# 88	RGB-PanSharpen_AOI_3_Paris_img1845.tif read
# 89	RGB-PanSharpen_AOI_3_Paris_img462.tif read
# 90	RGB-PanSharpen_AOI_3_Paris_img622.tif read
# 91	RGB-PanSharpen_AOI_3_Paris_img882.tif read
# 92	RGB-PanSharpen_AOI_3_Paris_img1844.tif read
# 93	RGB-PanSharpen_AOI_3_Paris_img876.tif read
# 94	RGB-PanSharpen_AOI_3_Paris_img1103.tif read
# 95	RGB-PanSharpen_AOI_3_Paris_img1149.tif read
# 96	RGB-PanSharpen_AOI_3_Paris_img189.tif read
# 97	RGB-PanSharpen_AOI_3_Paris_img935.tif read
# 98	RGB-PanSharpen_AOI_3_Paris_img1082.tif read
# 99	RGB-PanSharpen_AOI_3_Paris_img395.tif read
# 100	RGB-PanSharpen_AOI_3_Paris_img49.tif read
# 101	RGB-PanSharpen_AOI_3_Paris_img219.tif read
# 102	RGB-PanSharpen_AOI_3_Paris_img1824.tif read
# 103	RGB-PanSharpen_AOI_3_Paris_img980.tif read
# 104	RGB-PanSharpen_AOI_3_Paris_img1219.tif read
# 105	RGB-PanSharpen_AOI_3_Paris_img306.tif read
# 106	RGB-PanSharpen_AOI_3_Paris_img1724.tif read
# 107	RGB-PanSharpen_AOI_3_Paris_img816.tif read
# 108	RGB-PanSharpen_AOI_3_Paris_img1872.tif read
# 109	RGB-PanSharpen_AOI_3_Paris_img1245.tif read
# 110	RGB-PanSharpen_AOI_3_Paris_img544.tif read
# 111	RGB-PanSharpen_AOI_3_Paris_img958.tif read
# 112	RGB-PanSharpen_AOI_3_Paris_img1155.tif read
# 113	RGB-PanSharpen_AOI_3_Paris_img492.tif read
# 114	RGB-PanSharpen_AOI_3_Paris_img820.tif read
# 115	RGB-PanSharpen_AOI_3_Paris_img853.tif read
# 116	RGB-PanSharpen_AOI_3_Paris_img827.tif read
# 117	RGB-PanSharpen_AOI_3_Paris_img1158.tif read
# 118	RGB-PanSharpen_AOI_3_Paris_img1648.tif read
# 119	RGB-PanSharpen_AOI_3_Paris_img476.tif read
# 120	RGB-PanSharpen_AOI_3_Paris_img1654.tif read
# 121	RGB-PanSharpen_AOI_3_Paris_img986.tif read
# 122	RGB-PanSharpen_AOI_3_Paris_img1095.tif read
# 123	RGB-PanSharpen_AOI_3_Paris_img1172.tif read
# 124	RGB-PanSharpen_AOI_3_Paris_img283.tif read
# 125	RGB-PanSharpen_AOI_3_Paris_img451.tif read
# 126	RGB-PanSharpen_AOI_3_Paris_img263.tif read
# 127	RGB-PanSharpen_AOI_3_Paris_img1666.tif read
# 128	RGB-PanSharpen_AOI_3_Paris_img1735.tif read
# 129	RGB-PanSharpen_AOI_3_Paris_img1118.tif read
# 130	RGB-PanSharpen_AOI_3_Paris_img703.tif read
# 131	RGB-PanSharpen_AOI_3_Paris_img679.tif read
# 132	RGB-PanSharpen_AOI_3_Paris_img1644.tif read
# 133	RGB-PanSharpen_AOI_3_Paris_img1581.tif read
# 134	RGB-PanSharpen_AOI_3_Paris_img1632.tif read
# 135	RGB-PanSharpen_AOI_3_Paris_img1755.tif read
# 136	RGB-PanSharpen_AOI_3_Paris_img1855.tif read
# 137	RGB-PanSharpen_AOI_3_Paris_img370.tif read
# 138	RGB-PanSharpen_AOI_3_Paris_img971.tif read
# 139	RGB-PanSharpen_AOI_3_Paris_img1432.tif read
# 140	RGB-PanSharpen_AOI_3_Paris_img1525.tif read
# 141	RGB-PanSharpen_AOI_3_Paris_img1276.tif read
# 142	RGB-PanSharpen_AOI_3_Paris_img1807.tif read
# 143	RGB-PanSharpen_AOI_3_Paris_img1725.tif read
# 144	RGB-PanSharpen_AOI_3_Paris_img1754.tif read
# 145	RGB-PanSharpen_AOI_3_Paris_img6.tif read
# 146	RGB-PanSharpen_AOI_3_Paris_img975.tif read
# 147	RGB-PanSharpen_AOI_3_Paris_img1692.tif read
# 148	RGB-PanSharpen_AOI_3_Paris_img1429.tif read
# 149	RGB-PanSharpen_AOI_3_Paris_img867.tif read
# 150	RGB-PanSharpen_AOI_3_Paris_img819.tif read
# 151	RGB-PanSharpen_AOI_3_Paris_img1140.tif read
# 152	RGB-PanSharpen_AOI_3_Paris_img1197.tif read
# 153	RGB-PanSharpen_AOI_3_Paris_img914.tif read
# 154	RGB-PanSharpen_AOI_3_Paris_img1170.tif read
# 155	RGB-PanSharpen_AOI_3_Paris_img1822.tif read
# 156	RGB-PanSharpen_AOI_3_Paris_img1506.tif read
# 157	RGB-PanSharpen_AOI_3_Paris_img991.tif read
# 158	RGB-PanSharpen_AOI_3_Paris_img1800.tif read
# 159	RGB-PanSharpen_AOI_3_Paris_img1489.tif read
# 160	RGB-PanSharpen_AOI_3_Paris_img372.tif read
# 161	RGB-PanSharpen_AOI_3_Paris_img1109.tif read
# 162	RGB-PanSharpen_AOI_3_Paris_img182.tif read
# 163	RGB-PanSharpen_AOI_3_Paris_img1396.tif read
# 164	RGB-PanSharpen_AOI_3_Paris_img418.tif read
# 165	RGB-PanSharpen_AOI_3_Paris_img334.tif read
# 166	RGB-PanSharpen_AOI_3_Paris_img1071.tif read
# 167	RGB-PanSharpen_AOI_3_Paris_img951.tif read
# 168	RGB-PanSharpen_AOI_3_Paris_img743.tif read
# 169	RGB-PanSharpen_AOI_3_Paris_img1665.tif read
# 170	RGB-PanSharpen_AOI_3_Paris_img624.tif read
# 171	RGB-PanSharpen_AOI_3_Paris_img1022.tif read
# 172	RGB-PanSharpen_AOI_3_Paris_img70.tif read
# 173	RGB-PanSharpen_AOI_3_Paris_img638.tif read
# 174	RGB-PanSharpen_AOI_3_Paris_img953.tif read
# 175	RGB-PanSharpen_AOI_3_Paris_img681.tif read
# 176	RGB-PanSharpen_AOI_3_Paris_img1430.tif read
# 177	RGB-PanSharpen_AOI_3_Paris_img1297.tif read
# 178	RGB-PanSharpen_AOI_3_Paris_img1608.tif read
# 179	RGB-PanSharpen_AOI_3_Paris_img859.tif read
# 180	RGB-PanSharpen_AOI_3_Paris_img1393.tif read
# 181	RGB-PanSharpen_AOI_3_Paris_img4.tif read
# 182	RGB-PanSharpen_AOI_3_Paris_img304.tif read
# 183	RGB-PanSharpen_AOI_3_Paris_img1796.tif read
# 184	RGB-PanSharpen_AOI_3_Paris_img629.tif read
# 185	RGB-PanSharpen_AOI_3_Paris_img1857.tif read
# 186	RGB-PanSharpen_AOI_3_Paris_img1137.tif read
# 187	RGB-PanSharpen_AOI_3_Paris_img21.tif read
# 188	RGB-PanSharpen_AOI_3_Paris_img344.tif read
# 189	RGB-PanSharpen_AOI_3_Paris_img471.tif read
# 190	RGB-PanSharpen_AOI_3_Paris_img1712.tif read
# 191	RGB-PanSharpen_AOI_3_Paris_img642.tif read
# 192	RGB-PanSharpen_AOI_3_Paris_img750.tif read
# 193	RGB-PanSharpen_AOI_3_Paris_img1305.tif read
# 194	RGB-PanSharpen_AOI_3_Paris_img26.tif read
# 195	RGB-PanSharpen_AOI_3_Paris_img817.tif read
# 196	RGB-PanSharpen_AOI_3_Paris_img581.tif read
# 197	RGB-PanSharpen_AOI_3_Paris_img453.tif read
# 198	RGB-PanSharpen_AOI_3_Paris_img494.tif read
# 199	RGB-PanSharpen_AOI_3_Paris_img1653.tif read
# 200	RGB-PanSharpen_AOI_3_Paris_img720.tif read
# 201	RGB-PanSharpen_AOI_3_Paris_img1564.tif read
# 202	RGB-PanSharpen_AOI_3_Paris_img1182.tif read
# 203	RGB-PanSharpen_AOI_3_Paris_img127.tif read
# 204	RGB-PanSharpen_AOI_3_Paris_img1527.tif read
# 205	RGB-PanSharpen_AOI_3_Paris_img1028.tif read
# 206	RGB-PanSharpen_AOI_3_Paris_img1817.tif read
# 207	RGB-PanSharpen_AOI_3_Paris_img1263.tif read
# 208	RGB-PanSharpen_AOI_3_Paris_img1239.tif read
# 209	RGB-PanSharpen_AOI_3_Paris_img1400.tif read
# 210	RGB-PanSharpen_AOI_3_Paris_img1811.tif read
# 211	RGB-PanSharpen_AOI_3_Paris_img123.tif read
# 212	RGB-PanSharpen_AOI_3_Paris_img512.tif read
# 213	RGB-PanSharpen_AOI_3_Paris_img507.tif read
# 214	RGB-PanSharpen_AOI_3_Paris_img768.tif read
# 215	RGB-PanSharpen_AOI_3_Paris_img47.tif read
# 216	RGB-PanSharpen_AOI_3_Paris_img392.tif read
# 217	RGB-PanSharpen_AOI_3_Paris_img956.tif read
# 218	RGB-PanSharpen_AOI_3_Paris_img478.tif read
# 219	RGB-PanSharpen_AOI_3_Paris_img88.tif read
# 220	RGB-PanSharpen_AOI_3_Paris_img724.tif read
# 221	RGB-PanSharpen_AOI_3_Paris_img1121.tif read
# 222	RGB-PanSharpen_AOI_3_Paris_img1792.tif read
# 223	RGB-PanSharpen_AOI_3_Paris_img1704.tif read
# 224	RGB-PanSharpen_AOI_3_Paris_img1264.tif read
# 225	RGB-PanSharpen_AOI_3_Paris_img766.tif read
# 226	RGB-PanSharpen_AOI_3_Paris_img1852.tif read
# 227	RGB-PanSharpen_AOI_3_Paris_img650.tif read
# 228	RGB-PanSharpen_AOI_3_Paris_img102.tif read
# 229	RGB-PanSharpen_AOI_3_Paris_img412.tif read
# 230	RGB-PanSharpen_AOI_3_Paris_img838.tif read
# 231	RGB-PanSharpen_AOI_3_Paris_img714.tif read
# 232	RGB-PanSharpen_AOI_3_Paris_img1415.tif read
# 233	RGB-PanSharpen_AOI_3_Paris_img755.tif read
# 234	RGB-PanSharpen_AOI_3_Paris_img59.tif read
# 235	RGB-PanSharpen_AOI_3_Paris_img1736.tif read
# 236	RGB-PanSharpen_AOI_3_Paris_img1480.tif read
# 237	RGB-PanSharpen_AOI_3_Paris_img811.tif read
# 238	RGB-PanSharpen_AOI_3_Paris_img1040.tif read
# 239	RGB-PanSharpen_AOI_3_Paris_img1912.tif read
# 240	RGB-PanSharpen_AOI_3_Paris_img1879.tif read
# 241	RGB-PanSharpen_AOI_3_Paris_img245.tif read
# 242	RGB-PanSharpen_AOI_3_Paris_img1373.tif read
# 243	RGB-PanSharpen_AOI_3_Paris_img1547.tif read
# 244	RGB-PanSharpen_AOI_3_Paris_img1509.tif read
# 245	RGB-PanSharpen_AOI_3_Paris_img949.tif read
# 246	RGB-PanSharpen_AOI_3_Paris_img1009.tif read
# 247	RGB-PanSharpen_AOI_3_Paris_img1081.tif read
# 248	RGB-PanSharpen_AOI_3_Paris_img278.tif read
# 249	RGB-PanSharpen_AOI_3_Paris_img321.tif read
# 250	RGB-PanSharpen_AOI_3_Paris_img807.tif read
# 251	RGB-PanSharpen_AOI_3_Paris_img1268.tif read
# 252	RGB-PanSharpen_AOI_3_Paris_img1414.tif read
# 253	RGB-PanSharpen_AOI_3_Paris_img1431.tif read
# 254	RGB-PanSharpen_AOI_3_Paris_img1814.tif read
# 255	RGB-PanSharpen_AOI_3_Paris_img1583.tif read
# 256	RGB-PanSharpen_AOI_3_Paris_img1141.tif read
# 257	RGB-PanSharpen_AOI_3_Paris_img1253.tif read
# 258	RGB-PanSharpen_AOI_3_Paris_img1261.tif read
# 259	RGB-PanSharpen_AOI_3_Paris_img501.tif read
# 260	RGB-PanSharpen_AOI_3_Paris_img913.tif read
# 261	RGB-PanSharpen_AOI_3_Paris_img1742.tif read
# 262	RGB-PanSharpen_AOI_3_Paris_img673.tif read
# 263	RGB-PanSharpen_AOI_3_Paris_img665.tif read
# 264	RGB-PanSharpen_AOI_3_Paris_img209.tif read
# 265	RGB-PanSharpen_AOI_3_Paris_img1763.tif read
# 266	RGB-PanSharpen_AOI_3_Paris_img1534.tif read
# 267	RGB-PanSharpen_AOI_3_Paris_img391.tif read
# 268	RGB-PanSharpen_AOI_3_Paris_img46.tif read
# 269	RGB-PanSharpen_AOI_3_Paris_img1812.tif read
# 270	RGB-PanSharpen_AOI_3_Paris_img1635.tif read
# 271	RGB-PanSharpen_AOI_3_Paris_img1032.tif read
# 272	RGB-PanSharpen_AOI_3_Paris_img1017.tif read
# 273	RGB-PanSharpen_AOI_3_Paris_img664.tif read
# 274	RGB-PanSharpen_AOI_3_Paris_img1235.tif read
# 275	RGB-PanSharpen_AOI_3_Paris_img1147.tif read
# 276	RGB-PanSharpen_AOI_3_Paris_img108.tif read
# 277	RGB-PanSharpen_AOI_3_Paris_img1312.tif read
# 278	RGB-PanSharpen_AOI_3_Paris_img1422.tif read
# 279	RGB-PanSharpen_AOI_3_Paris_img1383.tif read
# 280	RGB-PanSharpen_AOI_3_Paris_img260.tif read
# 281	RGB-PanSharpen_AOI_3_Paris_img1036.tif read
# 282	RGB-PanSharpen_AOI_3_Paris_img634.tif read
# 283	RGB-PanSharpen_AOI_3_Paris_img1008.tif read
# 284	RGB-PanSharpen_AOI_3_Paris_img1246.tif read
# 285	RGB-PanSharpen_AOI_3_Paris_img1828.tif read
# 286	RGB-PanSharpen_AOI_3_Paris_img1309.tif read
# 287	RGB-PanSharpen_AOI_3_Paris_img215.tif read
# 288	RGB-PanSharpen_AOI_3_Paris_img813.tif read
# 289	RGB-PanSharpen_AOI_3_Paris_img751.tif read
# 290	RGB-PanSharpen_AOI_3_Paris_img282.tif read
# 291	RGB-PanSharpen_AOI_3_Paris_img604.tif read
# 292	RGB-PanSharpen_AOI_3_Paris_img1701.tif read
# 293	RGB-PanSharpen_AOI_3_Paris_img988.tif read
# 294	RGB-PanSharpen_AOI_3_Paris_img1586.tif read
# 295	RGB-PanSharpen_AOI_3_Paris_img233.tif read
# 296	RGB-PanSharpen_AOI_3_Paris_img240.tif read
# 297	RGB-PanSharpen_AOI_3_Paris_img482.tif read
# 298	RGB-PanSharpen_AOI_3_Paris_img1685.tif read
# 299	RGB-PanSharpen_AOI_3_Paris_img602.tif read
# 300	RGB-PanSharpen_AOI_3_Paris_img1577.tif read
# 301	RGB-PanSharpen_AOI_3_Paris_img1840.tif read
# 302	RGB-PanSharpen_AOI_3_Paris_img627.tif read
# 303	RGB-PanSharpen_AOI_3_Paris_img626.tif read
# 304	RGB-PanSharpen_AOI_3_Paris_img1470.tif read
# 305	RGB-PanSharpen_AOI_3_Paris_img353.tif read
# 306	RGB-PanSharpen_AOI_3_Paris_img1201.tif read
# 307	RGB-PanSharpen_AOI_3_Paris_img1686.tif read
# 308	RGB-PanSharpen_AOI_3_Paris_img926.tif read
# 309	RGB-PanSharpen_AOI_3_Paris_img1176.tif read
# 310	RGB-PanSharpen_AOI_3_Paris_img1013.tif read
# 311	RGB-PanSharpen_AOI_3_Paris_img561.tif read
# 312	RGB-PanSharpen_AOI_3_Paris_img139.tif read
# 313	RGB-PanSharpen_AOI_3_Paris_img109.tif read
# 314	RGB-PanSharpen_AOI_3_Paris_img788.tif read
# 315	RGB-PanSharpen_AOI_3_Paris_img1273.tif read
# 316	RGB-PanSharpen_AOI_3_Paris_img1294.tif read
# 317	RGB-PanSharpen_AOI_3_Paris_img317.tif read
# 318	RGB-PanSharpen_AOI_3_Paris_img1120.tif read
# 319	RGB-PanSharpen_AOI_3_Paris_img669.tif read
# 320	RGB-PanSharpen_AOI_3_Paris_img1733.tif read
# 321	RGB-PanSharpen_AOI_3_Paris_img118.tif read
# 322	RGB-PanSharpen_AOI_3_Paris_img1485.tif read
# 323	RGB-PanSharpen_AOI_3_Paris_img904.tif read
# 324	RGB-PanSharpen_AOI_3_Paris_img1108.tif read
# 325	RGB-PanSharpen_AOI_3_Paris_img403.tif read
# 326	RGB-PanSharpen_AOI_3_Paris_img1330.tif read
# 327	RGB-PanSharpen_AOI_3_Paris_img1124.tif read
# 328	RGB-PanSharpen_AOI_3_Paris_img1114.tif read
# 329	RGB-PanSharpen_AOI_3_Paris_img158.tif read
# 330	RGB-PanSharpen_AOI_3_Paris_img1076.tif read
# 331	RGB-PanSharpen_AOI_3_Paris_img887.tif read
# 332	RGB-PanSharpen_AOI_3_Paris_img941.tif read
# 333	RGB-PanSharpen_AOI_3_Paris_img735.tif read
# 334	RGB-PanSharpen_AOI_3_Paris_img50.tif read
# 335	RGB-PanSharpen_AOI_3_Paris_img903.tif read
# 336	RGB-PanSharpen_AOI_3_Paris_img500.tif read
# 337	RGB-PanSharpen_AOI_3_Paris_img380.tif read
# 338	RGB-PanSharpen_AOI_3_Paris_img780.tif read
# 339	RGB-PanSharpen_AOI_3_Paris_img1038.tif read
# 340	RGB-PanSharpen_AOI_3_Paris_img147.tif read
# 341	RGB-PanSharpen_AOI_3_Paris_img506.tif read
# 342	RGB-PanSharpen_AOI_3_Paris_img841.tif read
# 343	RGB-PanSharpen_AOI_3_Paris_img1740.tif read
# 344	RGB-PanSharpen_AOI_3_Paris_img1011.tif read
# 345	RGB-PanSharpen_AOI_3_Paris_img597.tif read
# 346	RGB-PanSharpen_AOI_3_Paris_img455.tif read
# 347	RGB-PanSharpen_AOI_3_Paris_img1679.tif read
# 348	RGB-PanSharpen_AOI_3_Paris_img272.tif read
# 349	RGB-PanSharpen_AOI_3_Paris_img830.tif read
# 350	RGB-PanSharpen_AOI_3_Paris_img1290.tif read
# 351	RGB-PanSharpen_AOI_3_Paris_img1112.tif read
# 352	RGB-PanSharpen_AOI_3_Paris_img1360.tif read
# 353	RGB-PanSharpen_AOI_3_Paris_img1402.tif read
# 354	RGB-PanSharpen_AOI_3_Paris_img1711.tif read
# 355	RGB-PanSharpen_AOI_3_Paris_img1768.tif read
# 356	RGB-PanSharpen_AOI_3_Paris_img746.tif read
# 357	RGB-PanSharpen_AOI_3_Paris_img191.tif read
# 358	RGB-PanSharpen_AOI_3_Paris_img1825.tif read
# 359	RGB-PanSharpen_AOI_3_Paris_img474.tif read
# 360	RGB-PanSharpen_AOI_3_Paris_img1034.tif read
# 361	RGB-PanSharpen_AOI_3_Paris_img1614.tif read
# 362	RGB-PanSharpen_AOI_3_Paris_img994.tif read
# 363	RGB-PanSharpen_AOI_3_Paris_img1334.tif read
# 364	RGB-PanSharpen_AOI_3_Paris_img930.tif read
# 365	RGB-PanSharpen_AOI_3_Paris_img410.tif read
# 366	RGB-PanSharpen_AOI_3_Paris_img1678.tif read
# 367	RGB-PanSharpen_AOI_3_Paris_img1885.tif read
# 368	RGB-PanSharpen_AOI_3_Paris_img1615.tif read
# 369	RGB-PanSharpen_AOI_3_Paris_img1150.tif read
# 370	RGB-PanSharpen_AOI_3_Paris_img32.tif read
# 371	RGB-PanSharpen_AOI_3_Paris_img1658.tif read
# 372	RGB-PanSharpen_AOI_3_Paris_img1528.tif read
# 373	RGB-PanSharpen_AOI_3_Paris_img1592.tif read
# 374	RGB-PanSharpen_AOI_3_Paris_img1770.tif read
# 375	RGB-PanSharpen_AOI_3_Paris_img923.tif read
# 376	RGB-PanSharpen_AOI_3_Paris_img791.tif read
# 377	RGB-PanSharpen_AOI_3_Paris_img328.tif read
# 378	RGB-PanSharpen_AOI_3_Paris_img429.tif read
# 379	RGB-PanSharpen_AOI_3_Paris_img513.tif read
# 380	RGB-PanSharpen_AOI_3_Paris_img203.tif read
# 381	RGB-PanSharpen_AOI_3_Paris_img452.tif read
# 382	RGB-PanSharpen_AOI_3_Paris_img101.tif read
# 383	RGB-PanSharpen_AOI_3_Paris_img1339.tif read
# 384	RGB-PanSharpen_AOI_3_Paris_img977.tif read
# 385	RGB-PanSharpen_AOI_3_Paris_img34.tif read
# 386	RGB-PanSharpen_AOI_3_Paris_img159.tif read
# 387	RGB-PanSharpen_AOI_3_Paris_img599.tif read
# 388	RGB-PanSharpen_AOI_3_Paris_img1728.tif read
# 389	RGB-PanSharpen_AOI_3_Paris_img891.tif read
# 390	RGB-PanSharpen_AOI_3_Paris_img1417.tif read
# 391	RGB-PanSharpen_AOI_3_Paris_img1179.tif read
# 392	RGB-PanSharpen_AOI_3_Paris_img661.tif read
# 393	RGB-PanSharpen_AOI_3_Paris_img1779.tif read
# 394	RGB-PanSharpen_AOI_3_Paris_img774.tif read
# 395	RGB-PanSharpen_AOI_3_Paris_img1587.tif read
# 396	RGB-PanSharpen_AOI_3_Paris_img909.tif read
# 397	RGB-PanSharpen_AOI_3_Paris_img843.tif read
# 398	RGB-PanSharpen_AOI_3_Paris_img1049.tif read
# 399	RGB-PanSharpen_AOI_3_Paris_img384.tif read
# 400	RGB-PanSharpen_AOI_3_Paris_img463.tif read
# 401	RGB-PanSharpen_AOI_3_Paris_img1255.tif read
# 402	RGB-PanSharpen_AOI_3_Paris_img1668.tif read
# 403	RGB-PanSharpen_AOI_3_Paris_img1772.tif read
# 404	RGB-PanSharpen_AOI_3_Paris_img1207.tif read
# 405	RGB-PanSharpen_AOI_3_Paris_img1390.tif read
# 406	RGB-PanSharpen_AOI_3_Paris_img1318.tif read
# 407	RGB-PanSharpen_AOI_3_Paris_img1856.tif read
# 408	RGB-PanSharpen_AOI_3_Paris_img1335.tif read
# 409	RGB-PanSharpen_AOI_3_Paris_img680.tif read
# 410	RGB-PanSharpen_AOI_3_Paris_img742.tif read
# 411	RGB-PanSharpen_AOI_3_Paris_img1749.tif read
# 412	RGB-PanSharpen_AOI_3_Paris_img3.tif read
# 413	RGB-PanSharpen_AOI_3_Paris_img605.tif read
# 414	RGB-PanSharpen_AOI_3_Paris_img1909.tif read
# 415	RGB-PanSharpen_AOI_3_Paris_img1250.tif read
# 416	RGB-PanSharpen_AOI_3_Paris_img1029.tif read
# 417	RGB-PanSharpen_AOI_3_Paris_img1154.tif read
# 418	RGB-PanSharpen_AOI_3_Paris_img1208.tif read
# 419	RGB-PanSharpen_AOI_3_Paris_img434.tif read
# 420	RGB-PanSharpen_AOI_3_Paris_img692.tif read
# 421	RGB-PanSharpen_AOI_3_Paris_img1553.tif read
# 422	RGB-PanSharpen_AOI_3_Paris_img595.tif read
# 423	RGB-PanSharpen_AOI_3_Paris_img1308.tif read
# 424	RGB-PanSharpen_AOI_3_Paris_img173.tif read
# 425	RGB-PanSharpen_AOI_3_Paris_img217.tif read
# 426	RGB-PanSharpen_AOI_3_Paris_img579.tif read
# 427	RGB-PanSharpen_AOI_3_Paris_img1016.tif read
# 428	RGB-PanSharpen_AOI_3_Paris_img1826.tif read
# 429	RGB-PanSharpen_AOI_3_Paris_img517.tif read
# 430	RGB-PanSharpen_AOI_3_Paris_img792.tif read
# 431	RGB-PanSharpen_AOI_3_Paris_img185.tif read
# 432	RGB-PanSharpen_AOI_3_Paris_img1278.tif read
# 433	RGB-PanSharpen_AOI_3_Paris_img193.tif read
# 434	RGB-PanSharpen_AOI_3_Paris_img1555.tif read
# 435	RGB-PanSharpen_AOI_3_Paris_img721.tif read
# 436	RGB-PanSharpen_AOI_3_Paris_img1810.tif read
# 437	RGB-PanSharpen_AOI_3_Paris_img1337.tif read
# 438	RGB-PanSharpen_AOI_3_Paris_img1093.tif read
# 439	RGB-PanSharpen_AOI_3_Paris_img1573.tif read
# 440	RGB-PanSharpen_AOI_3_Paris_img946.tif read
# 441	RGB-PanSharpen_AOI_3_Paris_img1202.tif read
# 442	RGB-PanSharpen_AOI_3_Paris_img1706.tif read
# 443	RGB-PanSharpen_AOI_3_Paris_img959.tif read
# 444	RGB-PanSharpen_AOI_3_Paris_img1404.tif read
# 445	RGB-PanSharpen_AOI_3_Paris_img90.tif read
# 446	RGB-PanSharpen_AOI_3_Paris_img1311.tif read
# 447	RGB-PanSharpen_AOI_3_Paris_img1301.tif read
# 448	RGB-PanSharpen_AOI_3_Paris_img1052.tif read
# 449	RGB-PanSharpen_AOI_3_Paris_img228.tif read
# 450	RGB-PanSharpen_AOI_3_Paris_img1442.tif read
# 451	RGB-PanSharpen_AOI_3_Paris_img1629.tif read
# 452	RGB-PanSharpen_AOI_3_Paris_img165.tif read
# 453	RGB-PanSharpen_AOI_3_Paris_img368.tif read
# 454	RGB-PanSharpen_AOI_3_Paris_img62.tif read
# 455	RGB-PanSharpen_AOI_3_Paris_img1059.tif read
# 456	RGB-PanSharpen_AOI_3_Paris_img976.tif read
# 457	RGB-PanSharpen_AOI_3_Paris_img1132.tif read
# 458	RGB-PanSharpen_AOI_3_Paris_img1274.tif read
# 459	RGB-PanSharpen_AOI_3_Paris_img1716.tif read
# 460	RGB-PanSharpen_AOI_3_Paris_img43.tif read
# 461	RGB-PanSharpen_AOI_3_Paris_img894.tif read
# 462	RGB-PanSharpen_AOI_3_Paris_img1187.tif read
# 463	RGB-PanSharpen_AOI_3_Paris_img693.tif read
# 464	RGB-PanSharpen_AOI_3_Paris_img232.tif read
# 465	RGB-PanSharpen_AOI_3_Paris_img966.tif read
# 466	RGB-PanSharpen_AOI_3_Paris_img443.tif read
# 467	RGB-PanSharpen_AOI_3_Paris_img1627.tif read
# 468	RGB-PanSharpen_AOI_3_Paris_img1865.tif read
# 469	RGB-PanSharpen_AOI_3_Paris_img343.tif read
# 470	RGB-PanSharpen_AOI_3_Paris_img1336.tif read
# 471	RGB-PanSharpen_AOI_3_Paris_img1449.tif read
# 472	RGB-PanSharpen_AOI_3_Paris_img269.tif read
# 473	RGB-PanSharpen_AOI_3_Paris_img208.tif read
# 474	RGB-PanSharpen_AOI_3_Paris_img78.tif read
# 475	RGB-PanSharpen_AOI_3_Paris_img1551.tif read
# 476	RGB-PanSharpen_AOI_3_Paris_img608.tif read
# 477	RGB-PanSharpen_AOI_3_Paris_img1727.tif read
# 478	RGB-PanSharpen_AOI_3_Paris_img1203.tif read
# 479	RGB-PanSharpen_AOI_3_Paris_img857.tif read
# 480	RGB-PanSharpen_AOI_3_Paris_img837.tif read
# 481	RGB-PanSharpen_AOI_3_Paris_img663.tif read
# 482	RGB-PanSharpen_AOI_3_Paris_img1443.tif read
# 483	RGB-PanSharpen_AOI_3_Paris_img795.tif read
# 484	RGB-PanSharpen_AOI_3_Paris_img1163.tif read
# 485	RGB-PanSharpen_AOI_3_Paris_img1379.tif read
# 486	RGB-PanSharpen_AOI_3_Paris_img773.tif read
# 487	RGB-PanSharpen_AOI_3_Paris_img1766.tif read
# 488	RGB-PanSharpen_AOI_3_Paris_img110.tif read
# 489	RGB-PanSharpen_AOI_3_Paris_img741.tif read
# 490	RGB-PanSharpen_AOI_3_Paris_img254.tif read
# 491	RGB-PanSharpen_AOI_3_Paris_img1902.tif read
# 492	RGB-PanSharpen_AOI_3_Paris_img1647.tif read
# 493	RGB-PanSharpen_AOI_3_Paris_img651.tif read
# 494	RGB-PanSharpen_AOI_3_Paris_img387.tif read
# 495	RGB-PanSharpen_AOI_3_Paris_img672.tif read
# 496	RGB-PanSharpen_AOI_3_Paris_img528.tif read
# 497	RGB-PanSharpen_AOI_3_Paris_img1523.tif read
# 498	RGB-PanSharpen_AOI_3_Paris_img944.tif read
# 499	RGB-PanSharpen_AOI_3_Paris_img1867.tif read
# 500	RGB-PanSharpen_AOI_3_Paris_img27.tif read
# Images were read
# Training model 8e96126f-592c-4180-a9e5-c0e1546527bc
# start train net
# Generated 1500 patches
# Generated 500 patches
# 2023-07-15 22:08:02.444457: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:08:02.444554: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:08:02.444596: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:08:02.730411: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:08:02.730501: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:08:02.730546: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:08:02.730594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5417 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/2500
# 2023-07-15 22:08:05.066383: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-07-15 22:08:05.311795: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:437] Could not create cudnn handle: CUDNN_STATUS_NOT_INITIALIZED
# 2023-07-15 22:08:05.311829: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:441] Memory usage: 5958795264 bytes free, 8361213952 bytes total.
# 2023-07-15 22:08:05.311846: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:451] Possibly insufficient driver version: 520.61.5
# 2023-07-15 22:08:05.311858: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at conv_ops_fused_impl.h:625 : UNIMPLEMENTED: DNN library is not found.
# Traceback (most recent call last):
#   File "/home/jovyan/deep-unet-for-satellite-image-segmentation/train_unet.py", line 91, in <module>
#     train_net()
#   File "/home/jovyan/deep-unet-for-satellite-image-segmentation/train_unet.py", line 84, in train_net
#     model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=N_EPOCHS,
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py", line 53, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.UnimplementedError: Graph execution error:
#
# Detected at node 'model/conv2d/Relu' defined at (most recent call last):
#     File "/home/jovyan/deep-unet-for-satellite-image-segmentation/train_unet.py", line 91, in <module>
#       train_net()
#     File "/home/jovyan/deep-unet-for-satellite-image-segmentation/train_unet.py", line 84, in train_net
#       model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=N_EPOCHS,
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1742, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1338, in train_function
#       return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1322, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1303, in run_step
#       outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1080, in train_step
#       y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 569, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py", line 321, in call
#       return self.activation(outputs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/activations.py", line 321, in relu
#       return backend.relu(
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/backend.py", line 5397, in relu
#       x = tf.nn.relu(x)
# Node: 'model/conv2d/Relu'
# DNN library is not found.
# 	 [[{{node model/conv2d/Relu}}]] [Op:__inference_train_function_8301]

# %% [markdown]
# Now we have a Model saved in a weights folder in our directory. Now we will try and test this model on a random image in the test data set.
#
# The predict fscript takes 2 parameters. The name of the model file that you want to use, or "latest" if u want to use the latest model. And it takes the name of the image that you want to make a prediction for. We have just set it to take a random image from the test set every time.

# %%
# !rm /home/jovyan/work/output/*

randimgnum = random.randint(0,len(os.listdir("/home/jovyan/data/test/PS-RGB/")))
img2show = os.listdir("/home/jovyan/data/test/PS-RGB/")[randimgnum]
gtif = gdal.Open("/home/jovyan/data/test/PS-RGB/" + img2show)
image = gtif.ReadAsArray()
plt.imshow(reshape_as_image(image))

# !python3 ~/deep-unet-for-satellite-image-segmentation/predict.py latest {img2show}
# Out:
# rm: cannot remove '/home/jovyan/work/output/*': No such file or directory
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2023-07-15 22:46:00.602818: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-15 22:46:00.625313: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-15 22:46:00.923149: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-15 22:46:01.360167: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 22:46:01.373486: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Weights Folder Already Exists
# /home/jovyan/deep-unet-for-satellite-image-segmentation/weights/79718c1b-70a5-49da-b9e6-bdad6fe4873dunet_weights.hdf5
# Traceback (most recent call last):
#   File "/home/jovyan/deep-unet-for-satellite-image-segmentation/predict.py", line 82, in <module>
#     img = tiff.imread('/home/jovyan/data/test/PS-RGB/{}'.format(test_id))
#   File "/usr/local/lib/python3.10/dist-packages/tifffile/tifffile.py", line 1094, in imread
#     with TiffFile(
#   File "/usr/local/lib/python3.10/dist-packages/tifffile/tifffile.py", line 4035, in __init__
#     fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#   File "/usr/local/lib/python3.10/dist-packages/tifffile/tifffile.py", line 14020, in __init__
#     self.open()
#   File "/usr/local/lib/python3.10/dist-packages/tifffile/tifffile.py", line 14035, in open
#     self._fh = open(
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/data/test/PS-RGB/home/jovyan/data/test/PS-RGB/SN2_buildings_test_public_AOI_3_Paris_PS-RGB_img644.tif'

# %% [markdown]
# Ok we just generated a prediction for the image shown above. Lets see what it looks like

# %%
gtif = gdal.Open('/home/jovyan/work/output/result.tif')
result = gtif.ReadAsArray()

gtif = gdal.Open('/home/jovyan/work/output/map.tif')
map = gtif.ReadAsArray()

plt.subplots(1,3,figsize=(20,5))
plt.subplot(1,3,1)
plt.imshow(reshape_as_image(image))
plt.subplot(1,3,2)
plt.imshow(reshape_as_image(result))
plt.subplot(1,3,3)
plt.imshow(reshape_as_image(map))
plt.show()

gtif = None

# %% [markdown]
# Well, as you can see the prediction is not that great.
